# %% [markdown]
# # Pertemuan 1 - Pengenalan Data Science
#
# **Nama Lengkap:** Suryani Tangdiaga
#
# **NIM:** 250401020097
#
# **Kelas:** Kelas IF405

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
nama = "Mahasiswa Informatika"
angkatan = 2024
ipk = 3.75
aktif = True

print(f"Nama     : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK      : {ipk}")
print(f"Aktif    : {aktif}")
# Out:
# Nama     : Mahasiswa Informatika
# Angkatan : 2024
# IPK      : 3.75
# Aktif    : True

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("\nTools Data Science yang akan kita pelajari:")

for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Budi Santoso", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Budi Santoso dari Informatika, angkatan 2024.

# %% [markdown]
# ## Kesimpulan
#
# Pada pertemuan pertama ini dipelajari konsep dasar Data Science dan penggunaan Python Notebook sebagai media praktikum. Materi yang dipelajari meliputi output sederhana, penggunaan variabel dan tipe data dasar, list dan perulangan, serta pembuatan fungsi sederhana. Temuan utama dari praktikum ini adalah Python dapat digunakan untuk mengolah data dan membuat program sederhana dengan mudah. Keterbatasan pada pertemuan ini adalah belum dilakukan analisis data yang kompleks maupun penerapan machine learning sehingga materi masih bersifat pengenalan dasar.
